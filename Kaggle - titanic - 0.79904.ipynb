# %%
import pandas as pd

# %% [markdown]
# ### Load Dataset

# %%
train = pd.read_csv("data/train.csv", index_col = "PassengerId")
print(train.shape)
train.head()
# Out:
# (891, 11)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv("data/test.csv", index_col ="PassengerId")

print(test.shape)
test.head()
# Out:
# (418, 10)
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Encording Sex

# %%
train["Sex_encord"] = train["Sex"].replace("male", 0 ).replace("female", 1)

print(train.shape)
train[["Sex", "Sex_encord"]].head()
# Out:
# (891, 12)
#                 Sex  Sex_encord
# PassengerId
# 1              male           0
# 2            female           1
# 3            female           1
# 4            female           1
# 5              male           0

# %%
test["Sex_encord"] = test["Sex"].replace("male", 0 ).replace("female", 1)

print(test.shape)
test[["Sex", "Sex_encord"]].head()
# Out:
# (418, 11)
#                 Sex  Sex_encord
# PassengerId
# 892            male           0
# 893          female           1
# 894            male           0
# 895            male           0
# 896          female           1

# %% [markdown]
# ### Fill in missing Fare

# %%
test["Fare"] = test["Fare"].fillna(0)

test[test["Fare"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Sex_encord]
# Index: []

# %% [markdown]
# ### Encord Embarked

# %%
# C == 0, S == 1, Q == 2
# 2 * S = Q?
# S + S = Q?

# One Hot Encording
# True == 1, False == 0
# C == [True, False, False]
# S == [False, True, False]
# Q == [False, False, True]

train["Embarked_C"] = train["Embarked"] == "C"
train["Embarked_S"] = train["Embarked"] == "S"
train["Embarked_Q"] = train["Embarked"] == "Q"
print(train.shape)
train[["Embarked", "Embarked_C", "Embarked_S", "Embarked_Q"]].head()
# Out:
# (891, 15)
#             Embarked  Embarked_C  Embarked_S  Embarked_Q
# PassengerId
# 1                  S       False        True       False
# 2                  C        True       False       False
# 3                  S       False        True       False
# 4                  S       False        True       False
# 5                  S       False        True       False

# %%
test["Embarked_C"] = test["Embarked"] == "C"
test["Embarked_S"] = test["Embarked"] == "S"
test["Embarked_Q"] = test["Embarked"] == "Q"
print(test.shape)
test[["Embarked", "Embarked_C", "Embarked_S", "Embarked_Q"]].head()
# Out:
# (418, 14)
#             Embarked  Embarked_C  Embarked_S  Embarked_Q
# PassengerId
# 892                Q       False       False        True
# 893                S       False        True       False
# 894                Q       False       False        True
# 895                S       False        True       False
# 896                S       False        True       False

# %% [markdown]
# ### Making age section

# %%
train.loc[train["Age"] < 15, "AgeType"] = "Young"
train.loc[(train["Age"] >= 15) & (train["Age"] < 30), "AgeType"] = "Medium"
train.loc[train["Age"] >= 30, "AgeType"] = "Old"

train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              Sex_encord  Embarked_C  Embarked_S  Embarked_Q AgeType
# PassengerId
# 1                     0       False        True       False  Medium
# 2                     1        True       False       False     Old
# 3                     1       False        True       False  Medium
# 4                     1       False        True       False     Old
# 5                     0       False        True       False     Old

# %%
test
# Out:
#              Pclass                                               Name  \
# PassengerId
# 892               3                                   Kelly, Mr. James
# 893               3                   Wilkes, Mrs. James (Ellen Needs)
# 894               2                          Myles, Mr. Thomas Francis
# 895               3                                   Wirz, Mr. Albert
# 896               3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
# 908            male  35.0      0      0              233734   12.3500
# 909            male  21.0      0      0                2692    7.2250
# 910          female  27.0      1      0    STON/O2. 3101270    7.9250
# 911          female  45.0      0      0                2696    7.2250
# 912            male  55.0      1      0            PC 17603   59.4000
# 913            male   9.0      0      1             C 17368    3.1708
# 914          female   NaN      0      0            PC 17598   31.6833
# 915            male  21.0      0      1            PC 17597   61.3792
# 916          female  48.0      1      3            PC 17608  262.3750
# 917            male  50.0      1      0           A/5. 3337   14.5000
# 918          female  22.0      0      1              113509   61.9792
# 919            male  22.5      0      0                2698    7.2250
# 920            male  41.0      0      0              113054   30.5000
# 921            male   NaN      2      0                2662   21.6792
# ...             ...   ...    ...    ...                 ...       ...
# 1280           male  21.0      0      0              364858    7.7500
# 1281           male   6.0      3      1              349909   21.0750
# 1282           male  23.0      0      0               12749   93.5000
# 1283         female  51.0      0      1            PC 17592   39.4000
# 1284           male  13.0      0      2           C.A. 2673   20.2500
# 1285           male  47.0      0      0          C.A. 30769   10.5000
# 1286           male  29.0      3      1              315153   22.0250
# 1287         female  18.0      1      0               13695   60.0000
# 1288           male  24.0      0      0              371109    7.2500
# 1289         female  48.0      1      1               13567   79.2000
# 1290           male  22.0      0      0              347065    7.7750
# 1291           male  31.0      0      0               21332    7.7333
# 1292         female  30.0      0      0               36928  164.8667
# 1293           male  38.0      1      0               28664   21.0000
# 1294         female  22.0      0      1              112378   59.4000
# 1295           male  17.0      0      0              113059   47.1000
# 1296           male  43.0      1      0               17765   27.7208
# 1297           male  20.0      0      0       SC/PARIS 2166   13.8625
# 1298           male  23.0      1      0               28666   10.5000
# 1299           male  50.0      1      1              113503  211.5000
# 1300         female   NaN      0      0              334915    7.7208
# 1301         female   3.0      1      1  SOTON/O.Q. 3101315   13.7750
# 1302         female   NaN      0      0              365237    7.7500
# 1303         female  37.0      1      0               19928   90.0000
# 1304         female  28.0      0      0              347086    7.7750
# 1305           male   NaN      0      0           A.5. 3236    8.0500
# 1306         female  39.0      0      0            PC 17758  108.9000
# 1307           male  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 1308           male   NaN      0      0              359309    8.0500
# 1309           male   NaN      1      1                2668   22.3583
#
#                        Cabin Embarked  Sex_encord  Embarked_C  Embarked_S  \
# PassengerId
# 892                      NaN        Q           0       False       False
# 893                      NaN        S           1       False        True
# 894                      NaN        Q           0       False       False
# 895                      NaN        S           0       False        True
# 896                      NaN        S           1       False        True
# 897                      NaN        S           0       False        True
# 898                      NaN        Q           1       False       False
# 899                      NaN        S           0       False        True
# 900                      NaN        C           1        True       False
# 901                      NaN        S           0       False        True
# 902                      NaN        S           0       False        True
# 903                      NaN        S           0       False        True
# 904                      B45        S           1       False        True
# 905                      NaN        S           0       False        True
# 906                      E31        S           1       False        True
# 907                      NaN        C           1        True       False
# 908                      NaN        Q           0       False       False
# 909                      NaN        C           0        True       False
# 910                      NaN        S           1       False        True
# 911                      NaN        C           1        True       False
# 912                      NaN        C           0        True       False
# 913                      NaN        S           0       False        True
# 914                      NaN        S           1       False        True
# 915                      NaN        C           0        True       False
# 916          B57 B59 B63 B66        C           1        True       False
# 917                      NaN        S           0       False        True
# 918                      B36        C           1        True       False
# 919                      NaN        C           0        True       False
# 920                      A21        S           0       False        True
# 921                      NaN        C           0        True       False
# ...                      ...      ...         ...         ...         ...
# 1280                     NaN        Q           0       False       False
# 1281                     NaN        S           0       False        True
# 1282                     B24        S           0       False        True
# 1283                     D28        S           1       False        True
# 1284                     NaN        S           0       False        True
# 1285                     NaN        S           0       False        True
# 1286                     NaN        S           0       False        True
# 1287                     C31        S           1       False        True
# 1288                     NaN        Q           0       False       False
# 1289                     B41        C           1        True       False
# 1290                     NaN        S           0       False        True
# 1291                     NaN        Q           0       False       False
# 1292                      C7        S           1       False        True
# 1293                     NaN        S           0       False        True
# 1294                     NaN        C           1        True       False
# 1295                     NaN        S           0       False        True
# 1296                     D40        C           0        True       False
# 1297                     D38        C           0        True       False
# 1298                     NaN        S           0       False        True
# 1299                     C80        C           0        True       False
# 1300                     NaN        Q           1       False       False
# 1301                     NaN        S           1       False        True
# 1302                     NaN        Q           1       False       False
# 1303                     C78        Q           1       False       False
# 1304                     NaN        S           1       False        True
# 1305                     NaN        S           0       False        True
# 1306                    C105        C           1        True       False
# 1307                     NaN        S           0       False        True
# 1308                     NaN        S           0       False        True
# 1309                     NaN        C           0        True       False
#
#              Embarked_Q
# PassengerId
# 892                True
# 893               False
# 894                True
# 895               False
# 896               False
# 897               False
# 898                True
# 899               False
# 900               False
# 901               False
# 902               False
# 903               False
# 904               False
# 905               False
# 906               False
# 907               False
# 908                True
# 909               False
# 910               False
# 911               False
# 912               False
# 913               False
# 914               False
# 915               False
# 916               False
# 917               False
# 918               False
# 919               False
# 920               False
# 921               False
# ...                 ...
# 1280               True
# 1281              False
# 1282              False
# 1283              False
# 1284              False
# 1285              False
# 1286              False
# 1287              False
# 1288               True
# 1289              False
# 1290              False
# 1291               True
# 1292              False
# 1293              False
# 1294              False
# 1295              False
# 1296              False
# 1297              False
# 1298              False
# 1299              False
# 1300               True
# 1301              False
# 1302               True
# 1303               True
# 1304              False
# 1305              False
# 1306              False
# 1307              False
# 1308              False
# 1309              False
#
# [418 rows x 14 columns]

# %%
test[test["Age"].isnull()]
# Out:
#              Pclass                                               Name  \
# PassengerId
# 902               3                                   Ilieff, Mr. Ylio
# 914               1               Flegenheim, Mrs. Alfred (Antoinette)
# 921               3                                  Samaan, Mr. Elias
# 925               3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 928               3                                Roth, Miss. Sarah A
# 931               3                                      Hee, Mr. Ling
# 933               1                        Franklin, Mr. Thomas Parham
# 939               3                           Shaughnessy, Mr. Patrick
# 946               2                  Mangiavacchi, Mr. Serafino Emilio
# 950               3                          Davison, Mr. Thomas Henry
# 957               2  Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...
# 968               3                                   Miles, Mr. Frank
# 975               3                               Demetri, Mr. Marinko
# 976               2                              Lamb, Mr. John Joseph
# 977               3                                 Khalil, Mr. Betros
# 957                S           1       False        True       False
# 968                S           0       False        True       False
# 975                S           0       False        True       False
# 976                Q           0       False       False        True
# 977                C           0        True       False       False
# 980                Q           1       False       False        True
# 983                S           0       False        True       False
# 985                S           0       False        True       False
# 994                Q           0       False       False        True
# 999                Q           0       False       False        True
# 1000               S           0       False        True       False
# 1003               Q           1       False       False        True
# 1008               C           0        True       False       False
# 1013               Q           0       False       False        True
# 1016               Q           0       False       False        True
# 1019               Q           1       False       False        True
# 1024               S           1       False        True       False
# 1025               C           0        True       False       False
# 1038               S           0       False        True       False
# 1040               S           0       False        True       False
# ...              ...         ...         ...         ...         ...
# 1160               S           1       False        True       False
# 1163               Q           0       False       False        True
# 1165               Q           1       False       False        True
# 1166               C           0        True       False       False
# 1174               Q           1       False       False        True
# 1178               S           0       False        True       False
# 1180               C           0        True       False       False
# 1181               S           0       False        True       False
# 1182               S           0       False        True       False
# 1184               C           0        True       False       False
# 1189               C           0        True       False       False
# 1193               C           0        True       False       False
# 1196               Q           1       False       False        True
# 1204               S           0       False        True       False
# 1224               C           0        True       False       False
# 1231               C           0        True       False       False
# 1234               S           0       False        True       False
# 1236               S           0       False        True       False
# 1249               S           0       False        True       False
# 1250               Q           0       False       False        True
# 1257               S           1       False        True       False
# 1258               C           0        True       False       False
# 1272               Q           0       False       False        True
# 1274               S           1       False        True       False
# 1276               S           0       False        True       False
# 1300               Q           1       False       False        True
# 1302               Q           1       False       False        True
# 1305               S           0       False        True       False
# 1308               S           0       False        True       False
# 1309               C           0        True       False       False
#
# [86 rows x 14 columns]

# %%
train["Age(fill)"] = train["Age"]
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
#
#              Sex_encord  Embarked_C  Embarked_S  Embarked_Q AgeType  Age(fill)
# PassengerId
# 1                     0       False        True       False  Medium       22.0
# 2                     1        True       False       False     Old       38.0
# 3                     1       False        True       False  Medium       26.0
# 4                     1       False        True       False     Old       35.0
# 5                     0       False        True       False     Old       35.0

# %%
train.loc[(train["Age(fill)"].isnull()) & (train["Pclass"]== 1), "Age(fill)"] = 38.233441
train.loc[(train["Age(fill)"].isnull()) & (train["Pclass"]== 2), "Age(fill)"] = 29.877630
train.loc[(train["Age(fill)"].isnull()) & (train["Pclass"]== 3), "Age(fill)"] = 25.140620
train.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C
#
#              Sex_encord  Embarked_C  Embarked_S  Embarked_Q AgeType  Age(fill)
# PassengerId
# 1                     0       False        True       False  Medium   22.00000
# 2                     1        True       False       False     Old   38.00000
# 3                     1       False        True       False  Medium   26.00000
# 4                     1       False        True       False     Old   35.00000
# 5                     0       False        True       False     Old   35.00000
# 6                     0       False       False        True     NaN   25.14062
# 7                     0       False        True       False     Old   54.00000
# 8                     0       False        True       False   Young    2.00000
# 9                     1       False        True       False  Medium   27.00000
# 10                    1        True       False       False   Young   14.00000

# %% [markdown]
# ### Making test data age section

# %%
test["Age(fill)"] = test["Age"]
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_encord  \
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        
  38.5      0      0  SOTON/O.Q. 3101262    7.2500
# 1308           male   NaN      0      0              359309    8.0500
# 1309           male   NaN      1      1                2668   22.3583
#
#                        Cabin Embarked  Sex_encord  Embarked_C  Embarked_S  \
# PassengerId
# 892                      NaN        Q           0       False       False
# 893                      NaN        S           1       False        True
# 894                      NaN        Q           0       False       False
# 895                      NaN        S           0       False        True
# 896                      NaN        S           1       False        True
# 897                      NaN        S           0       False        True
# 898                      NaN        Q           1       False       False
# 899                      NaN        S           0       False        True
# 900                      NaN        C           1        True       False
# 901                      NaN        S           0       False        True
# 902                      NaN        S           0       False        True
# 903                      NaN        S           0       False        True
# 904                      B45        S           1       False        True
# 905                      NaN        S           0       False        True
# 906                      E31        S           1       False        True
# 907                      NaN        C           1        True       False
# 908                      NaN        Q           0       False       False
# 909                      NaN        C           0        True       False
# 910                      NaN        S           1       False        True
# 911                      NaN        C           1        True       False
# 912                      NaN        C           0        True       False
# 913                      NaN        S           0       False        True
# 914                      NaN        S           1       False        True
# 915                      NaN        C           0        True       False
# 916          B57 B59 B63 B66        C           1        True       False
# 917                      NaN        S           0       False        True
# 918                      B36        C           1        True       False
# 919                      NaN        C           0        True       False
# 920                      A21        S           0       False        True
# 921                      NaN        C           0        True       False
# ...                      ...      ...         ...         ...         ...
# 1280                     NaN        Q           0       False       False
# 1281                     NaN        S           0       False        True
# 1282                     B24        S           0       False        True
# 1283                     D28        S           1       False        True
# 1284                     NaN        S           0       False        True
# 1285                     NaN        S           0       False        True
# 1286                     NaN        S           0       False        True
# 1287                     C31        S           1       False        True
# 1288                     NaN        Q           0       False       False
# 1289                     B41        C           1        True       False
# 1290                     NaN        S           0       False        True
# 1291                     NaN        Q           0       False       False
# 1292                      C7        S           1       False        True
# 1293                     NaN        S           0       False        True
# 1294                     NaN        C           1        True       False
# 1295                     NaN        S           0       False        True
# 1296                     D40        C           0        True       False
# 1297                     D38        C           0        True       False
# 1298                     NaN        S           0       False        True
# 1299                     C80        C           0        True       False
# 1300                     NaN        Q           1       False       False
# 1301                     NaN        S           1       False        True
# 1302                     NaN        Q           1       False       False
# 1303                     C78        Q           1       False       False
# 1304                     NaN        S           1       False        True
# 1305                     NaN        S           0       False        True
# 1306                    C105        C           1        True       False
# 1307                     NaN        S           0       False        True
# 1308                     NaN        S           0       False        True
# 1309                     NaN        C           0        True       False
#
#              Embarked_Q  Age(fill)
# PassengerId
# 892                True       34.5
# 893               False       47.0
# 894                True       62.0
# 895               False       27.0
# 896               False       22.0
# 897               False       14.0
# 898                True       30.0
# 899               False       26.0
# 900               False       18.0
# 901               False       21.0
# 902               False        NaN
# 903               False       46.0
# 904               False       23.0
# 905               False       63.0
# 906               False       47.0
# 907               False       24.0
# 908                True       35.0
# 909               False       21.0
# 910               False       27.0
# 911               False       45.0
# 912               False       55.0
# 913               False        9.0
# 914               False        NaN
# 915               False       21.0
# 916               False       48.0
# 917               False       50.0
# 918               False       22.0
# 919               False       22.5
# 920               False       41.0
# 921               False        NaN
# ...                 ...        ...
# 1280               True       21.0
# 1281              False        6.0
# 1282              False       23.0
# 1283              False       51.0
# 1284              False       13.0
# 1285              False       47.0
# 1286              False       29.0
# 1287              False       18.0
# 1288               True       24.0
# 1289              False       48.0
# 1290              False       22.0
# 1291               True       31.0
# 1292              False       30.0
# 1293              False       38.0
# 1294              False       22.0
# 1295              False       17.0
# 1296              False       43.0
# 1297              False       20.0
# 1298              False       23.0
# 1299              False       50.0
# 1300               True        NaN
# 1301              False        3.0
# 1302               True        NaN
# 1303               True       37.0
# 1304              False       28.0
# 1305              False        NaN
# 1306              False       39.0
# 1307              False       38.5
# 1308              False        NaN
# 1309              False        NaN
#
# [418 rows x 15 columns]

# %%
test.loc[(train["Age(fill)"].isnull()) & (test["Pclass"]== 1), "Age(fill)"] = 38.233441
test.loc[(train["Age(fill)"].isnull()) & (test["Pclass"]== 2), "Age(fill)"] = 29.877630
test.loc[(train["Age(fill)"].isnull()) & (test["Pclass"]== 3), "Age(fill)"] = 25.140620
test.head(10)
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 897               3                    Svensson, Mr. Johan Cervin    male
# 898               3                          Connolly, Miss. Kate  female
# 899               2                  Caldwell, Mr. Albert Francis    male
# 900               3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 901               3                       Davies, Mr. John Samuel    male
#
#               Age  SibSp  Parch     Ticket     Fare Cabin Embarked  \
# PassengerId
# 892          34.5      0      0     330911   7.8292   NaN        Q
# 893          47.0      1      0     363272   7.0000   NaN        S
# 894          62.0      0      0     240276   9.6875   NaN        Q
# 895          27.0      0      0     315154   8.6625   NaN        S
# 896          22.0      1      1    3101298  12.2875   NaN        S
# 897          14.0      0      0       7538   9.2250   NaN        S
# 898          30.0      0      0     330972   7.6292   NaN        Q
# 899          26.0      1      1     248738  29.0000   NaN        S
# 900          18.0      0      0       2657   7.2292   NaN        C
# 901          21.0      2      0  A/4 48871  24.1500   NaN        S
#
#              Sex_encord  Embarked_C  Embarked_S  Embarked_Q  Age(fill)
# PassengerId
# 892                   0       False       False        True       34.5
# 893                   1       False        True       False       47.0
# 894                   0       False       False        True       62.0
# 895                   0       False        True       False       27.0
# 896                   1       False        True       False       22.0
# 897                   0       False        True       False       14.0
# 898                   1       False       False        True       30.0
# 899                   0       False        True       False       26.0
# 900                   1        True       False       False       18.0
# 901                   0       False        True       False       21.0

# %%
test.loc[test["Age"] < 15, "AgeType"] = "Young"
test.loc[(test["Age"] >= 15) & (test["Age"] < 30), "AgeType"] = "Medium"
test.loc[test["Age"] >= 30, "AgeType"] = "Old"

# %%
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_encord  \
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q           0
# 893          47.0      1      0   363272   7.0000   NaN        S           1
# 894          62.0      0      0   240276   9.6875   NaN        Q           0
# 895          27.0      0      0   315154   8.6625   NaN        S           0
# 896          22.0      1      1  3101298  12.2875   NaN        S           1
#
#              Embarked_C  Embarked_S  Embarked_Q  Age(fill) AgeType
# PassengerId
# 892               False       False        True       34.5     Old
# 893               False        True       False       47.0     Old
# 894               False       False        True       62.0     Old
# 895               False        True       False       27.0  Medium
# 896               False        True       False       22.0  Medium

# %% [markdown]
# ### Encord train data age section

# %%
train["Age_Old"] = train["AgeType"] == "Old"
train["Age_Medium"] = train["AgeType"] == "Medium"
train["Age_Young"] = train["AgeType"] == "Young"
print(train.shape)
train[["AgeType", "Age_Old", "Age_Medium", "Age_Young"]].head()
# Out:
# (891, 20)
#             AgeType  Age_Old  Age_Medium  Age_Young
# PassengerId
# 1            Medium    False        True      False
# 2               Old     True       False      False
# 3            Medium    False        True      False
# 4               Old     True       False      False
# 5               Old     True       False      False

# %% [markdown]
# ### Encord test data age section

# %%
test["Age_Old"] = test["AgeType"] == "Old"
test["Age_Medium"] = test["AgeType"] == "Medium"
test["Age_Young"] = test["AgeType"] == "Young"
print(test.shape)
test[["AgeType", "Age_Old", "Age_Medium", "Age_Young"]].head()
# Out:
# (418, 19)
#             AgeType  Age_Old  Age_Medium  Age_Young
# PassengerId
# 892             Old     True       False      False
# 893             Old     True       False      False
# 894             Old     True       False      False
# 895          Medium    False        True      False
# 896          Medium    False        True      False

# %% [markdown]
# ### Making Family Size

# %%
train["Single"]=(train["SibSp"]== 0) & (train["Parch"]== 0)
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  ... Sex_encord  \
# PassengerId                                                 ...
# 1                1      0         A/5 21171   7.2500   NaN  ...          0
# 2                1      0          PC 17599  71.2833   C85  ...          1
# 3                0      0  STON/O2. 3101282   7.9250   NaN  ...          1
# 4                1      0            113803  53.1000  C123  ...          1
# 5                0      0            373450   8.0500   NaN  ...          0
#
#              Embarked_C  Embarked_S  Embarked_Q  AgeType Age(fill)  Age_Old  \
# PassengerId
# 1                 False        True       False   Medium      22.0    False
# 2                  True       False       False      Old      38.0     True
# 3                 False        True       False   Medium      26.0    False
# 4                 False        True       False      Old      35.0     True
# 5                 False        True       False      Old      35.0     True
#
#              Age_Medium  Age_Young  Single
# PassengerId
# 1                  True      False   False
# 2                 False      False   False
# 3                  True      False    True
# 4                 False      False   False
# 5                 False      False    True
#
# [5 rows x 21 columns]

# %%
train["FamilySize"]=(train["SibSp"]) + (train["Parch"]) + 1
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin  ... Embarked_C  \
# PassengerId                                                 ...
# 1                1      0         A/5 21171   7.2500   NaN  ...      False
# 2                1      0          PC 17599  71.2833   C85  ...       True
# 3                0      0  STON/O2. 3101282   7.9250   NaN  ...      False
# 4                1      0            113803  53.1000  C123  ...      False
# 5                0      0            373450   8.0500   NaN  ...      False
#
#              Embarked_S  Embarked_Q  AgeType  Age(fill) Age_Old  Age_Medium  \
# PassengerId
# 1                  True       False   Medium       22.0   False        True
# 2                 False       False      Old       38.0    True       False
# 3                  True       False   Medium       26.0   False        True
# 4                  True       False      Old       35.0    True       False
# 5                  True       False      Old       35.0    True       False
#
#              Age_Young  Single  FamilySize
# PassengerId
# 1                False   False           2
# 2                False   False           2
# 3                False    True           1
# 4                False   False           2
# 5                False    True           1
#
# [5 rows x 22 columns]

# %%
train.loc[train["FamilySize"] < 2, "FamilyType"] = "Single"
train.loc[(train["FamilySize"] >= 2) & (train["FamilySize"] < 5), "FamilyType"] = "Nuclear"
train.loc[train["FamilySize"] >= 5, "FamilyType"] = "Big"

# %%
train[["FamilySize", "FamilyType"]].head(10)
# Out:
#              FamilySize FamilyType
# PassengerId
# 1                     2    Nuclear
# 2                     2    Nuclear
# 3                     1     Single
# 4                     2    Nuclear
# 5                     1     Single
# 6                     1     Single
# 7                     1     Single
# 8                     5        Big
# 9                     3    Nuclear
# 10                    2    Nuclear

# %% [markdown]
# ### Making Family Size for test data

# %%
test["Single"]=(test["SibSp"]== 0) & (test["Parch"]== 0)
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_encord  \
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q           0
# 893          47.0      1      0   363272   7.0000   NaN        S           1
# 894          62.0      0      0   240276   9.6875   NaN        Q           0
# 895          27.0      0      0   315154   8.6625   NaN        S           0
# 896          22.0      1      1  3101298  12.2875   NaN        S           1
#
#              Embarked_C  Embarked_S  Embarked_Q  Age(fill) AgeType  Age_Old  \
# PassengerId
# 892               False       False        True       34.5     Old     True
# 893               False        True       False       47.0     Old     True
# 894               False       False        True       62.0     Old     True
# 895               False        True       False       27.0  Medium    False
# 896               False        True       False       22.0  Medium    False
#
#              Age_Medium  Age_Young  Single
# PassengerId
# 892               False      False    True
# 893               False      False   False
# 894               False      False    True
# 895                True      False    True
# 896                True      False   False

# %%
test["FamilySize"]=(test["SibSp"]) + (test["Parch"]) + 1
test.head()
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked  ...  \
# PassengerId                                                       ...
# 892          34.5      0      0   330911   7.8292   NaN        Q  ...
# 893          47.0      1      0   363272   7.0000   NaN        S  ...
# 894          62.0      0      0   240276   9.6875   NaN        Q  ...
# 895          27.0      0      0   315154   8.6625   NaN        S  ...
# 896          22.0      1      1  3101298  12.2875   NaN        S  ...
#
#              Embarked_C  Embarked_S  Embarked_Q  Age(fill)  AgeType Age_Old  \
# PassengerId
# 892               False       False        True       34.5      Old    True
# 893               False        True       False       47.0      Old    True
# 894               False       False        True       62.0      Old    True
# 895               False        True       False       27.0   Medium   False
# 896               False        True       False       22.0   Medium   False
#
#              Age_Medium  Age_Young  Single  FamilySize
# PassengerId
# 892               False      False    True           1
# 893               False      False   False           2
# 894               False      False    True           1
# 895                True      False    True           1
# 896                True      False   False           3
#
# [5 rows x 21 columns]

# %%
test.loc[test["FamilySize"] < 2, "FamilyType"] = "Single"
test.loc[(test["FamilySize"] >= 2) & (test["FamilySize"] < 5), "FamilyType"] = "Nuclear"
test.loc[test["FamilySize"] >= 5, "FamilyType"] = "Big"

# %%
test[["FamilySize", "FamilyType"]].head(10)
# Out:
#              FamilySize FamilyType
# PassengerId
# 892                   1     Single
# 893                   2    Nuclear
# 894                   1     Single
# 895                   1     Single
# 896                   3    Nuclear
# 897                   1     Single
# 898                   1     Single
# 899                   3    Nuclear
# 900                   1     Single
# 901                   3    Nuclear

# %% [markdown]
# ### Encording Family Size

# %%
train["Family_Single"] = train["FamilyType"] == "Single"
train["Family_Nuclear"] = train["FamilyType"] == "Nuclear"
train["Family_Big"] = train["FamilyType"] == "Big"
print(train.shape)
train[["FamilyType", "Family_Single", "Family_Nuclear", "Family_Big"]].head()
# Out:
# (891, 26)
#             FamilyType  Family_Single  Family_Nuclear  Family_Big
# PassengerId
# 1              Nuclear          False            True       False
# 2              Nuclear          False            True       False
# 3               Single           True           False       False
# 4              Nuclear          False            True       False
# 5               Single           True           False       False

# %% [markdown]
# ### Encording Family Size for test data

# %%
test["Family_Single"] = test["FamilyType"] == "Single"
test["Family_Nuclear"] = test["FamilyType"] == "Nuclear"
test["Family_Big"] = test["FamilyType"] == "Big"
print(test.shape)
test[["FamilyType", "Family_Single", "Family_Nuclear", "Family_Big"]].head()
# Out:
# (418, 25)
#             FamilyType  Family_Single  Family_Nuclear  Family_Big
# PassengerId
# 892             Single           True           False       False
# 893            Nuclear          False            True       False
# 894             Single           True           False       False
# 895             Single           True           False       False
# 896            Nuclear          False            True       False

# %% [markdown]
# ## Train

# %%
feature_names = ["Pclass", "Sex_encord", "Fare", "Embarked_C", "Embarked_S", "Embarked_Q","Family_Single", "Family_Nuclear", "Family_Big", "Age_Old", "Age_Medium", "Age_Young"]


feature_names
# Out:
# ['Pclass',
#  'Sex_encord',
#  'Fare',
#  'Embarked_C',
#  'Embarked_S',
#  'Embarked_Q',
#  'Family_Single',
#  'Family_Nuclear',
#  'Family_Big',
#  'Age_Old',
#  'Age_Medium',
#  'Age_Young']

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (891, 12)
#              Pclass  Sex_encord     Fare  Embarked_C  Embarked_S  Embarked_Q  \
# PassengerId
# 1                 3           0   7.2500       False        True       False
# 2                 1           1  71.2833        True       False       False
# 3                 3           1   7.9250       False        True       False
# 4                 1           1  53.1000       False        True       False
# 5                 3           0   8.0500       False        True       False
#
#              Family_Single  Family_Nuclear  Family_Big  Age_Old  Age_Medium  \
# PassengerId
# 1                    False            True       False    False        True
# 2                    False            True       False     True       False
# 3                     True           False       False    False        True
# 4                    False            True       False     True       False
# 5                     True           False       False     True       False
#
#              Age_Young
# PassengerId
# 1                False
# 2                False
# 3                False
# 4                False
# 5                False

# %%
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (418, 12)
#              Pclass  Sex_encord     Fare  Embarked_C  Embarked_S  Embarked_Q  \
# PassengerId
# 892               3           0   7.8292       False       False        True
# 893               3           1   7.0000       False        True       False
# 894               2           0   9.6875       False       False        True
# 895               3           0   8.6625       False        True       False
# 896               3           1  12.2875       False        True       False
#
#              Family_Single  Family_Nuclear  Family_Big  Age_Old  Age_Medium  \
# PassengerId
# 892                   True           False       False     True       False
# 893                  False            True       False     True       False
# 894                   True           False       False     True       False
# 895                   True           False       False    False        True
# 896                  False            True       False    False        True
#
#              Age_Young
# PassengerId
# 892              False
# 893              False
# 894              False
# 895              False
# 896              False

# %%
label_name = "Survived"

y_train=train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (891,)
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

model
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
prediction = model.predict(X_test)
print(prediction.shape)
prediction[0:5]
# Out:
# (418,)
# array([0, 0, 0, 0, 1], dtype=int64)

# %%
submit = pd.read_csv("data/gender_submission.csv", index_col="PassengerId")
submit["Survived"] = prediction

print(submit.shape)
submit.head()
# Out:
# (418, 1)
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 1

# %%
submit.to_csv("decision-tree.csv")
