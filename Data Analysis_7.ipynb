# %% [markdown]
# ## Data Analysis_7

# %% [markdown]
# ### Configuration

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import matplotlib
from IPython.display import set_matplotlib_formats

mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

set_matplotlib_formats('retina')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-123ee8f7e166> in <module>
#       2 from IPython.display import set_matplotlib_formats
#       3
# ----> 4 mpl.rc('font', family='Malgun Gothic')
#       5 mpl.rc('axes', unicode_minus=False)
#       6
#
# NameError: name 'mpl' is not defined

# %% [markdown]
# ### Load Dataset

# %%
user_info = pd.read_csv("data/zigzag/user_info.csv")

print(user_info.shape)

user_info.head()

# %%
shop_info = pd.read_csv("data/zigzag/shop_info.csv")

print(shop_info.shape)

shop_info.head()

# %%
goods_info = pd.read_csv("data/zigzag/goods_info.csv")

print(goods_info.shape)

goods_info.head()

# %%
goods_info = goods_info.drop(['timestamp', 'image_type', 'image_width', 'image_height'], axis=1)

# %%
goods_info.head()

# %%
order_info = pd.read_csv("data/zigzag/order_info.csv")

print(order_info.shape)

order_info.head()

# %%
order_info["timestamp"] = pd.to_datetime(order_info["timestamp"])

order_info["timestamp(year)"] = order_info["timestamp"].dt.year
order_info["timestamp(month)"] = order_info["timestamp"].dt.month
order_info["timestamp(day)"] = order_info["timestamp"].dt.day
order_info["timestamp(hour)"] = order_info["timestamp"].dt.hour
order_info["timestamp(minute)"] = order_info["timestamp"].dt.minute
order_info["timestamp(second)"] = order_info["timestamp"].dt.second
order_info["timestamp(dayofweek)"] = order_info["timestamp"].dt.weekday_name

order_info.head()

# %%
user_event_logs = pd.read_csv("data/zigzag/user_event_logs.csv")

print(user_event_logs.shape)

user_event_logs.head()

# %%
user_event_logs["timestamp"] = pd.to_datetime(user_event_logs["timestamp"])

user_event_logs["timestamp(year)"] = user_event_logs["timestamp"].dt.year
user_event_logs["timestamp(month)"] = user_event_logs["timestamp"].dt.month
user_event_logs["timestamp(day)"] = user_event_logs["timestamp"].dt.day
user_event_logs["timestamp(hour)"] = user_event_logs["timestamp"].dt.hour
user_event_logs["timestamp(minute)"] = user_event_logs["timestamp"].dt.minute
user_event_logs["timestamp(second)"] = user_event_logs["timestamp"].dt.second
user_event_logs["timestamp(dayofweek)"] = user_event_logs["timestamp"].dt.weekday_name


user_event_logs.head()

# %% [markdown]
# ### 1. 사용자의 상세 정보 출력

# %%
user_info.head()
# Out:
#                             user_id   os  age
# 0  --PYPMX8QWg0ioT5zfORmU-S5Lln0lot  And   41
# 1  -16-xXbeDcvkZJtTpRwMi57Yo2ZQpORv  iOS   31
# 2  -1de9sT-MLwVVvnC0ncCLnqEqpSi3XSN  iOS   16
# 3  -3A3L2jnM55B_Q1bRXMjZ6sPnINIj-Y1  And   41
# 4  -3bhcSgPOIdQAPkPNcchxvECGqGQQ78k  And   42

# %%
user_info[user_info["user_id"] == "--PYPMX8QWg0ioT5zfORmU-S5Lln0lot"]
# Out:
#                             user_id   os  age
# 0  --PYPMX8QWg0ioT5zfORmU-S5Lln0lot  And   41

# %%
def find_user(user_id, finish = 'today'):
    profile = user_info[user_info["user_id"] == user_id]
    orders = order_info[order_info["user_id"] == user_id]
    logs = user_event_logs[user_event_logs["user_id"] == user_id]
    return profile, orders, logs

# %%
find_user("gni976f7oJAqbJCoOd9N7pupYq43qujw", finish = 'today')
# Out:
# (                               user_id   os  age
#  7006  gni976f7oJAqbJCoOd9N7pupYq43qujw  iOS   33,
#                    timestamp                           user_id  goods_id  \
#  842 2018-06-11 23:22:14.971  gni976f7oJAqbJCoOd9N7pupYq43qujw      2129
#
#       shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
#  842       32  24800             2018                 6              11
#
#       timestamp(hour)  timestamp(minute)  timestamp(second)  \
#  842               23                 22                 14
#
#      timestamp(dayofweek)
#  842               Monday  ,
#                       timestamp                           user_id event_origin  \
#  31026  2018-06-11 10:47:09.669  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  54129  2018-06-11 16:26:59.993  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  54135  2018-06-11 16:27:01.604  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  54145  2018-06-11 16:27:08.223  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  54179  2018-06-11 16:27:30.587  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  54311  2018-06-11 16:29:27.990  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  79032  2018-06-11 21:03:51.011  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  83718  2018-06-11 21:38:25.108  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  85694  2018-06-11 21:52:52.574  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  85699  2018-06-11 21:52:55.766  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  85957  2018-06-11 21:54:49.162  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  87530  2018-06-11 22:05:14.996  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  88519  2018-06-11 22:11:32.621  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  88527  2018-06-11 22:11:33.961  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  88883  2018-06-11 22:13:31.327  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  93576  2018-06-11 22:42:52.225  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  100027 2018-06-11 23:21:26.524  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#  100139 2018-06-11 23:22:03.228  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#
#             event_name  event_goods_id  event_shop_id  timestamp(year)  \
#  31026   app_page_view             NaN            NaN             2018
#  54129   enter_browser          4426.0           38.0             2018
#  54135   app_page_view             NaN            NaN             2018
#  54145   enter_browser          2129.0           32.0             2018
#  54179   app_page_view             NaN            NaN             2018
#  54311   enter_browser          2129.0           32.0             2018
#  79032   app_page_view             NaN            NaN             2018
#  83718   enter_browser          2129.0           32.0             2018
#  85694   app_page_view             NaN            NaN             2018
#  85699   enter_browser          2129.0           32.0             2018
#  85957   app_page_view             NaN            NaN             2018
#  87530   enter_browser          2129.0           32.0             2018
#  88519   app_page_view             NaN            NaN             2018
#  88527   enter_browser          2129.0           32.0             2018
#  88883    add_my_goods          7128.0           32.0             2018
#  93576   enter_browser          2129.0           32.0             2018
#  100027  enter_browser          2129.0           32.0             2018
#  100139  enter_browser          2129.0           32.0             2018
#
#          timestamp(month)  timestamp(day)  timestamp(hour)  timestamp(minute)  \
#  31026                  6              11               10                 47
#  54129                  6              11               16                 26
#  54135                  6              11               16                 27
#  54145                  6              11               16                 27
#  54179                  6              11               16                 27
#  54311                  6              11               16                 29
#  79032                  6              11               21                  3
#  83718                  6              11               21                 38
#  85694                  6              11               21                 52
#  85699                  6              11               21                 52
#  85957                  6              11               21                 54
#  87530                  6              11               22                  5
#  88519                  6              11               22                 11
#  88527                  6              11               22                 11
#  88883                  6              11               22                 13
#  93576                  6              11               22                 42
#  100027                 6              11               23                 21
#  100139                 6              11               23                 22
#
#          timestamp(second) timestamp(dayofweek)
#  31026                   9               Monday
#  54129                  59               Monday
#  54135                   1               Monday
#  54145                   8               Monday
#  54179                  30               Monday
#  54311                  27               Monday
#  79032                  51               Monday
#  83718                  25               Monday
#  85694                  52               Monday
#  85699                  55               Monday
#  85957                  49               Monday
#  87530                  14               Monday
#  88519                  32               Monday
#  88527                  33               Monday
#  88883                  31               Monday
#  93576                  52               Monday
#  100027                 26               Monday
#  100139                  3               Monday  )

# %%
# 특정사용자 찾기
user_id = "gni976f7oJAqbJCoOd9N7pupYq43qujw"

profile, orders, logs = find_user(user_id, finish = 'today')

# %%
profile
# Out:
#                                user_id   os  age
# 7006  gni976f7oJAqbJCoOd9N7pupYq43qujw  iOS   33

# %%
orders
# Out:
#                   timestamp                           user_id  goods_id  \
# 842 2018-06-11 23:22:14.971  gni976f7oJAqbJCoOd9N7pupYq43qujw      2129
#
#      shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
# 842       32  24800             2018                 6              11
#
#      timestamp(hour)  timestamp(minute)  timestamp(second)  \
# 842               23                 22                 14
#
#     timestamp(dayofweek)
# 842               Monday

# %%
logs.head()
# Out:
#                     timestamp                           user_id event_origin  \
# 31026 2018-06-11 10:47:09.669  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54129 2018-06-11 16:26:59.993  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54135 2018-06-11 16:27:01.604  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54145 2018-06-11 16:27:08.223  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54179 2018-06-11 16:27:30.587  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#
#           event_name  event_goods_id  event_shop_id  timestamp(year)  \
# 31026  app_page_view             NaN            NaN             2018
# 54129  enter_browser          4426.0           38.0             2018
# 54135  app_page_view             NaN            NaN             2018
# 54145  enter_browser          2129.0           32.0             2018
# 54179  app_page_view             NaN            NaN             2018
#
#        timestamp(month)  timestamp(day)  timestamp(hour)  timestamp(minute)  \
# 31026                 6              11               10                 47
# 54129                 6              11               16                 26
# 54135                 6              11               16                 27
# 54145                 6              11               16                 27
# 54179                 6              11               16                 27
#
#        timestamp(second) timestamp(dayofweek)
# 31026                  9               Monday
# 54129                 59               Monday
# 54135                  1               Monday
# 54145                  8               Monday
# 54179                 30               Monday

# %%
# 특정시간 이전까지만 가져오기
finish = pd.to_datetime("2018-06-11 18:00:00")

# 이렇게 하면 오후 6시 이전의 모든 구매 정보, 서비스 이용 내역은 배제하고 출력합니다.
profile, orders, logs = find_user(user_id, finish = finish)

# %%
profile
# Out:
#                                user_id   os  age
# 7006  gni976f7oJAqbJCoOd9N7pupYq43qujw  iOS   33

# %%
orders
# Out:
#                   timestamp                           user_id  goods_id  \
# 842 2018-06-11 23:22:14.971  gni976f7oJAqbJCoOd9N7pupYq43qujw      2129
#
#      shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
# 842       32  24800             2018                 6              11
#
#      timestamp(hour)  timestamp(minute)  timestamp(second)  \
# 842               23                 22                 14
#
#     timestamp(dayofweek)
# 842               Monday

# %%
logs
# Out:
#                      timestamp                           user_id event_origin  \
# 31026  2018-06-11 10:47:09.669  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54129  2018-06-11 16:26:59.993  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54135  2018-06-11 16:27:01.604  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54145  2018-06-11 16:27:08.223  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54179  2018-06-11 16:27:30.587  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 54311  2018-06-11 16:29:27.990  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 79032  2018-06-11 21:03:51.011  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 83718  2018-06-11 21:38:25.108  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 85694  2018-06-11 21:52:52.574  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 85699  2018-06-11 21:52:55.766  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 85957  2018-06-11 21:54:49.162  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 87530  2018-06-11 22:05:14.996  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 88519  2018-06-11 22:11:32.621  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 88527  2018-06-11 22:11:33.961  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 88883  2018-06-11 22:13:31.327  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 93576  2018-06-11 22:42:52.225  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 100027 2018-06-11 23:21:26.524  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
# 100139 2018-06-11 23:22:03.228  gni976f7oJAqbJCoOd9N7pupYq43qujw     my_goods
#
#            event_name  event_goods_id  event_shop_id  timestamp(year)  \
# 31026   app_page_view             NaN            NaN             2018
# 54129   enter_browser          4426.0           38.0             2018
# 54135   app_page_view             NaN            NaN             2018
# 54145   enter_browser          2129.0           32.0             2018
# 54179   app_page_view             NaN            NaN             2018
# 54311   enter_browser          2129.0           32.0             2018
# 79032   app_page_view             NaN            NaN             2018
# 83718   enter_browser          2129.0           32.0             2018
# 85694   app_page_view             NaN            NaN             2018
# 85699   enter_browser          2129.0           32.0             2018
# 85957   app_page_view             NaN            NaN             2018
# 87530   enter_browser          2129.0           32.0             2018
# 88519   app_page_view             NaN            NaN             2018
# 88527   enter_browser          2129.0           32.0             2018
# 88883    add_my_goods          7128.0           32.0             2018
# 93576   enter_browser          2129.0           32.0             2018
# 100027  enter_browser          2129.0           32.0             2018
# 100139  enter_browser          2129.0           32.0             2018
#
#         timestamp(month)  timestamp(day)  timestamp(hour)  timestamp(minute)  \
# 31026                  6              11               10                 47
# 54129                  6              11               16                 26
# 54135                  6              11               16                 27
# 54145                  6              11               16                 27
# 54179                  6              11               16                 27
# 54311                  6              11               16                 29
# 79032                  6              11               21                  3
# 83718                  6              11               21                 38
# 85694                  6              11               21                 52
# 85699                  6              11               21                 52
# 85957                  6              11               21                 54
# 87530                  6              11               22                  5
# 88519                  6              11               22                 11
# 88527                  6              11               22                 11
# 88883                  6              11               22                 13
# 93576                  6              11               22                 42
# 100027                 6              11               23                 21
# 100139                 6              11               23                 22
#
#         timestamp(second) timestamp(dayofweek)
# 31026                   9               Monday
# 54129                  59               Monday
# 54135                   1               Monday
# 54145                   8               Monday
# 54179                  30               Monday
# 54311                  27               Monday
# 79032                  51               Monday
# 83718                  25               Monday
# 85694                  52               Monday
# 85699                  55               Monday
# 85957                  49               Monday
# 87530                  14               Monday
# 88519                  32               Monday
# 88527                  33               Monday
# 88883                  31               Monday
# 93576                  52               Monday
# 100027                 26               Monday
# 100139                  3               Monday

# %%
# user_id 를 이용하여 하나로 합쳐주기
order_user_info = pd.merge(order_info, user_info, on = 'user_id', how='inner')

print(order_user_info.shape)

order_user_info.head()
# Out:
# (867, 14)
#                 timestamp                           user_id  goods_id  \
# 0 2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 2 2018-06-11 00:04:06.364  EyGjKYtSqZgqJ1ddKCtH5XwGirTyOH2P       646
# 3 2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 4 2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
#
#    shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
# 0       38  45000             2018                 6              11
# 1       12   9500             2018                 6              11
# 2       14  22000             2018                 6              11
# 3       46  29800             2018                 6              11
# 4       89  29000             2018                 6              11
#
#    timestamp(hour)  timestamp(minute)  timestamp(second) timestamp(dayofweek)  \
# 0                0                  0                 43               Monday
# 1                0                  2                 33               Monday
# 2                0                  4                  6               Monday
# 3                0                  4                 17               Monday
# 4                0                  5                 26               Monday
#
#     os  age
# 0  iOS   39
# 1  And   17
# 2  And   -1
# 3  And   34
# 4  And   17

# %%
# 나이가 -1 인 값을 찾기
order_user_info[order_user_info["age"] == -1]
# Out:
#                   timestamp                           user_id  goods_id  \
# 2   2018-06-11 00:04:06.364  EyGjKYtSqZgqJ1ddKCtH5XwGirTyOH2P       646
# 57  2018-06-11 00:42:22.451  MxzVx01SvanhSaaSVROjaPgPZgF-R8b7      6061
# 63  2018-06-11 00:46:43.845  9kBsnxkIY5hV-222s00gw6e3UXqC-L6R      2641
# 134 2018-06-11 02:23:02.453  ufMNuHl9t23qKlMWEJE9G5E_4OjSYFnO      6367
# 151 2018-06-11 02:42:41.540  Q3b6sc9u8wQp9D8N8QP5sKW5zAY_aM2E      4944
# 160 2018-06-11 03:07:08.628  RhkbkdW0nD2gQ5TQxdD3BBRnrxDKG5SR      2250
# 161 2018-06-11 03:08:35.512  UylP44AkHGty9mTL5in0hAgSgcLaHl5M      2974
# 166 2018-06-11 03:17:28.258  HJNmMLa3bmz8VE0Ci1_KIpiTQ6vGixRV      2452
# 170 2018-06-11 03:30:12.346  UXr4iQTAUER1ITIrM5vyhNOyjbqWogds      5972
# 182 2018-06-11 04:03:39.156  lm0nmeVGh6gZvxf2OVlWyPu_lz-zsjJk      2862
# 186 2018-06-11 04:40:30.536  X9nNV_VYXiOFubM0r856R-NbhTK1tDFv      1778
# 202 2018-06-11 06:52:47.293  eQP3wwSLBEyfCNooJaquF8AdxkLjCqdC      3994
# 206 2018-06-11 07:08:58.063  eV-6RqbXKDE727X34IcnIknQX8TCD96S       476
# 238 2018-06-11 08:53:11.205  UIvp-6ss33AixATQzTzxRMBHe0NqrQ6t      2153
# 243 2018-06-11 09:02:43.765  FpahGl20b_LXqR_udPLAtcq3cy1nfsMk      5756
# 285 2018-06-11 10:36:26.154  yIeogfPx0stcCf8h1-sZFl-XdjNESu14      2512
# 305 2018-06-11 11:11:40.876  Ewz2n045BIM7JXX8posui8HXWKnKdtgF      5121
# 319 2018-06-11 11:37:54.046  -4O8WnD8dT6nWho-4KbIm6TvnK4BmjX_       763
# 320 2018-06-11 12:46:50.689  -4O8WnD8dT6nWho-4KbIm6TvnK4BmjX_      4345
# 345 2018-06-11 12:14:06.265  V_A8Wkf5K9m1GQ1QrjvHXEf8D_uO79Ob      5965
# 347 2018-06-11 12:19:01.939  p2D2GCAIAcGkJKxEJ1W3byveAU68qYoS      5109
# 361 2018-06-11 12:29:11.599  jQSejDlDeNOTKx133RyFUaCTNZKzjhoX      3367
# 369 2018-06-11 12:47:55.035  _XJE9xWDMaM-JdQv1dmlE8pEVOP3T2LD      6125
# 407 2018-06-11 13:40:58.133  EitTUkeGdLFnbpKIs9GMAk0vAyfUTkrM      3311
# 450 2018-06-11 14:43:08.207  2yoE_ceHn4fZdo4Btojp2C8x4soikMwx      2820
# 489 2018-06-11 15:44:46.483  SiF-fubnIFJ1Fz1rV85EQWFm6nHYBGTq       145
# 490 2018-06-11 15:46:16.377  -EzeqHwqCE5w2DcivhEZT6OcjzIe-BnO      3359
# 531 2018-06-11 17:00:26.367  9FQjC96fplE1ydH7zuZg0Nn01sXS2m07      4757
# 585 2018-06-11 18:48:26.599  iIUKcdCRe3oEWUqbFIApcWJ1nb-cvVpw      5388
# 593 2018-06-11 18:58:50.306  P-1L7TGP_fipzYVNVNpEqZ4rSLpSPMRG      6479
# 614 2018-06-11 19:33:05.058  l9JS4TPS8W46BS0yKhI7uq5P2hJvlznM        19
# 623 2018-06-11 19:41:05.441  zgam4nm7bwsk1_XUDBKNNmQRKt6FUBFI       114
# 649 2018-06-11 20:16:42.571  CvcnHE9Vy1k_-FETUzKaUV01__A0vVjD      7043
# 656 2018-06-11 20:27:09.812  mT7W0kv5Q9AT9_cQ5QciqJ11ll3mBPBD       530
# 658 2018-06-11 20:31:37.003  zQTDNqRPz8R4ZYe_7vPpsD3I_0hNKOf4      3482
# 672 2018-06-11 20:47:06.062  WPk9FKp-raP29p3wzXX7EmMIl3_VL6_U      4449
# 678 2018-06-11 20:53:49.891  eGItwKpfB879lpbo38OA-x-z66lN5QT0       102
# 696 2018-06-11 21:18:29.683  8976RLa9-uAvHfF5W_4ejhvCD_HiTXsC       428
# 700 2018-06-11 21:19:45.249  cZiq9EuSz5a3F7XtynWc6IIG79so11eU      2137
# 752 2018-06-11 22:02:03.547  7Y_u3HZLnCyPnxuok8e5Lu5NGm8_UD_5      4376
# 776 2018-06-11 22:21:59.651  ylhZDaBjnJPDamtt0DT7bRQBEp8hgeFq        56
# 836 2018-06-11 23:17:46.258  WcRAA22j-KSwMIRncFChMDCz1Skf_T3i      1096
# 855 2018-06-11 23:34:39.923  VdxINSPDmWqar5NUJJTFjxC_cF0IOfFe      5113
#
#      shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
# 2         14  22000             2018                 6              11
# 57        14  54000             2018                 6              11
# 63        94  31900             2018                 6              11
# 134      194  19430             2018                 6              11
# 151      167  31350             2018                 6              11
# 160       93  18000             2018                 6              11
# 161      121  38000             2018                 6              11
# 166       18  46500             2018                 6              11
# 170      113  31500             2018                 6              11
# 182       60  28900             2018                 6              11
# 186       14  13000             2018                 6              11
# 202       14  19000             2018                 6              11
# 206       93  20000             2018                 6              11
# 238       63  25800             2018                 6              11
# 243       60  37500             2018                 6              11
# 285      145  41000             2018                 6              11
# 305       83  34000             2018                 6              11
# 319      189  20000             2018                 6              11
# 320       19  47500             2018                 6              11
# 345      110  38000             2018                 6              11
# 347       65  47900             2018                 6              11
# 361       22  12000             2018                 6              11
# 369        1  40800             2018                 6              11
# 407       65  29900             2018                 6              11
# 450       93  10000             2018                 6              11
# 489      100  22800             2018                 6              11
# 490       22  12200             2018                 6              11
# 531        2  22800             2018                 6              11
# 585       46  25000             2018                 6              11
# 593       77  16500             2018                 6              11
# 614       89  19000             2018                 6              11
# 623      138  13900             2018                 6              11
# 649      106  71000             2018                 6              11
# 656      185  15900             2018                 6              11
# 658      138  19900             2018                 6              11
# 672       28  23900             2018                 6              11
# 678      102  14000             2018                 6              11
# 696       64  41900             2018                 6              11
# 700       28  17960             2018                 6              11
# 752       32  17800             2018                 6              11
# 776      139  29900             2018                 6              11
# 836       63  27800             2018                 6              11
# 855      181  23800             2018                 6              11
#
#      timestamp(hour)  timestamp(minute)  timestamp(second)  \
# 2                  0                  4                  6
# 57                 0                 42                 22
# 63                 0                 46                 43
# 134                2                 23                  2
# 151                2                 42                 41
# 160                3                  7                  8
# 161                3                  8                 35
# 166                3                 17                 28
# 170                3                 30                 12
# 182                4                  3                 39
# 186                4                 40                 30
# 202                6                 52                 47
# 206                7                  8                 58
# 238                8                 53                 11
# 243                9                  2                 43
# 285               10                 36                 26
# 305               11                 11                 40
# 319               11                 37                 54
# 320               12                 46                 50
# 345               12                 14                  6
# 347               12                 19                  1
# 361               12                 29                 11
# 369               12                 47                 55
# 407               13                 40                 58
# 450               14                 43                  8
# 489               15                 44                 46
# 490               15                 46                 16
# 531               17                  0                 26
# 585               18                 48                 26
# 593               18                 58                 50
# 614               19                 33                  5
# 623               19                 41                  5
# 649               20                 16                 42
# 656               20                 27                  9
# 658               20                 31                 37
# 672               20                 47                  6
# 678               20                 53                 49
# 696               21                 18                 29
# 700               21                 19                 45
# 752               22                  2                  3
# 776               22                 21                 59
# 836               23                 17                 46
# 855               23                 34                 39
#
#     timestamp(dayofweek)   os  age
# 2                 Monday  And   -1
# 57                Monday  iOS   -1
# 63                Monday  iOS   -1
# 134               Monday  iOS   -1
# 151               Monday  iOS   -1
# 160               Monday  iOS   -1
# 161               Monday  iOS   -1
# 166               Monday  iOS   -1
# 170               Monday  iOS   -1
# 182               Monday  And   -1
# 186               Monday  iOS   -1
# 202               Monday  iOS   -1
# 206               Monday  iOS   -1
# 238               Monday  And   -1
# 243               Monday  iOS   -1
# 285               Monday  iOS   -1
# 305               Monday  iOS   -1
# 319               Monday  And   -1
# 320               Monday  And   -1
# 345               Monday  iOS   -1
# 347               Monday  iOS   -1
# 361               Monday  And   -1
# 369               Monday  And   -1
# 407               Monday  iOS   -1
# 450               Monday  iOS   -1
# 489               Monday  And   -1
# 490               Monday  iOS   -1
# 531               Monday  iOS   -1
# 585               Monday  iOS   -1
# 593               Monday  iOS   -1
# 614               Monday  iOS   -1
# 623               Monday  iOS   -1
# 649               Monday  And   -1
# 656               Monday  iOS   -1
# 658               Monday  And   -1
# 672               Monday  iOS   -1
# 678               Monday  And   -1
# 696               Monday  And   -1
# 700               Monday  iOS   -1
# 752               Monday  iOS   -1
# 776               Monday  iOS   -1
# 836               Monday  iOS   -1
# 855               Monday  iOS   -1

# %%
# 시간별 거래량 pivot table
table = pd.pivot_table(order_user_info, values = 'price', index = 'timestamp(hour)', aggfunc = ['sum'])

table
# Out:
#                      sum
#                    price
# timestamp(hour)
# 0                1479210
# 1                 990300
# 2                 787830
# 3                 467650
# 4                 304800
# 5                  47100
# 6                 192400
# 7                 430300
# 8                 437060
# 9                 581800
# 10               1009710
# 11                906000
# 12               1178050
# 13               1041400
# 14               1045800
# 15                662760
# 16                925100
# 17                681400
# 18                818320
# 19                918700
# 20               1081800
# 21               1399710
# 22               1444170
# 23                927950

# %%
# 나이대 설정
def make_generation(age):
    if age == -1:
        return '미입력'
    elif age / 10 >= 4.5:
        return "45+"
    elif age / 10 >= 4:
        return "40"
    elif age / 10 >= 3:
        return "30"
    elif age / 10 >= 2:
        return "20"
    else:
        return "10"

# %%
make_generation(23)
# Out:
# '20'

# %%
age_list = ['10', '20', '30', '40', '45+']
for i in age_list:
    order_user_info["age_0"] = order_user_info['age'].map(make_generation)
order_user_info.head()
# Out:
#                 timestamp                           user_id  goods_id  \
# 0 2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 2 2018-06-11 00:04:06.364  EyGjKYtSqZgqJ1ddKCtH5XwGirTyOH2P       646
# 3 2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 4 2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
#
#    shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
# 0       38  45000             2018                 6              11
# 1       12   9500             2018                 6              11
# 2       14  22000             2018                 6              11
# 3       46  29800             2018                 6              11
# 4       89  29000             2018                 6              11
#
#    timestamp(hour)  timestamp(minute)  timestamp(second) timestamp(dayofweek)  \
# 0                0                  0                 43               Monday
# 1                0                  2                 33               Monday
# 2                0                  4                  6               Monday
# 3                0                  4                 17               Monday
# 4                0                  5                 26               Monday
#
#     os  age age_0
# 0  iOS   39    30
# 1  And   17    10
# 2  And   -1   미입력
# 3  And   34    30
# 4  And   17    10

# %%
# 나이 -1 정리
order_user_info_clear_age = order_user_info[order_user_info["age"] != -1]

print(order_user_info_clear_age.shape)

order_user_info_clear_age
# Out:
# (824, 15)
#                   timestamp                           user_id  goods_id  \
# 0   2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1   2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 3   2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 4   2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
# 5   2018-06-11 00:05:35.182  GM0-EsJPHjkpteIpAQIwaCdUjU81lhW1        55
# 6   2018-06-11 00:06:14.314  lgvWxrv7r5RGklXSJqM2x6NUBZ5H-RQZ      2451
# 7   2018-06-11 00:08:39.716  LZZ0ktGq6hW685TFAQfcGNhsKVUEceHl      4278
# 8   2018-06-11 01:11:36.225  LZZ0ktGq6hW685TFAQfcGNhsKVUEceHl      2384
# 9   2018-06-11 00:11:30.954  Evz6xmsye1BP7i33rr_RAjwBRZ_AOsTZ       686
# 10  2018-06-11 00:12:12.469  _t38UxRGHDKAsgc7nJhxz0e7q3pIj-RD      4521
# 11  2018-06-11 00:13:40.279  2eb5qysY4MRSlB4wy9N6ZsfNffmvyoKY      1622
# 12  2018-06-11 00:14:32.171  3LGSst6B7iam6ua5uoPG_D43HkkIGY0v      6222
# 13  2018-06-11 00:14:53.858  OTgwvtiSLDoWj5gqc5k7oTQ4EJ19bpuj      3985
# 14  2018-06-11 00:16:24.729  1htAKqqU-G6Cqwhl1AQZdrcqm9i-xhn7       854
# 15  2018-06-11 00:16:58.463  hZrcB-RV5EqL94ysDGcrQ1TZKlhSeS7L      4318
# 16  2018-06-11 10:53:34.715  hZrcB-RV5EqL94ysDGcrQ1TZKlhSeS7L      6365
# 17  2018-06-11 00:16:59.727  qyHhjqtMFu8B7lG1OKT39sj1J6RJNGeZ      4583
# 18  2018-06-11 00:17:05.702  ejnC07Ro8itd1n2oCegwOIdrgoF8hT0O      3402
# 19  2018-06-11 00:17:08.555  45TmDQuhC0bjgTIsSStEj6ttHdgF_jOr      2418
# 20  2018-06-11 00:17:45.978  B3yaMZ62HOH0shQOKjo4QPV6PLcobUsT      6242
# 21  2018-06-11 00:18:21.226  -L2Awbp23c9b1o1R_do--BZEtPivAUua      2941
# 22  2018-06-11 00:18:42.937  3ntrLPHn8Xu0IsVQ1z00T2g1FnaJG6jf      1482
# 23  2018-06-11 00:32:50.981  3ntrLPHn8Xu0IsVQ1z00T2g1FnaJG6jf      3339
# 24  2018-06-11 00:18:45.243  R6PmigLc669neah2MZxxbIEWsTpEoww0       330
# 25  2018-06-11 00:20:15.178  XZcG-8HyZc10O7JvFYklwdrUZGTbCoi1      6241
# 26  2018-06-11 00:21:10.667  Vz_t7ZIWUi8wyzGGheiYnfEoKMfDLR60       993
# 27  2018-06-11 00:36:33.642  Vz_t7ZIWUi8wyzGGheiYnfEoKMfDLR60      2440
# 28  2018-06-11 00:21:16.753  6jvfNuWMFWuRpEKCk1J03XsrhEtXMX_H      2812
# 29  2018-06-11 00:21:55.869  sYFIv7ryLof2OGic7DnrYRb3BX3VPphc      2392
# 30  2018-06-11 00:22:20.782  UFa_urDGFk4NSBF2z_TpxyJFWuuREQa6      3846
# ..                      ...                               ...       ...
# 835 2018-06-11 23:17:24.021  1SZp7sMFWAfcLfGOZOWKLyDgfaIw2jT7      1887
# 837 2018-06-11 23:19:11.439  -1de9sT-MLwVVvnC0ncCLnqEqpSi3XSN       425
# 838 2018-06-11 23:19:22.321  k-spvw_JM19AoKmgbx26WpET5QCafMcg        79
# 839 2018-06-11 23:19:58.737  CiShnjZZLMl-FUQ854x2i94LoEfaSqJd      1444
# 840 2018-06-11 23:21:02.340  PHVH2uXe1uQA3we1oEv0CtHv65ydqhbT      6185
# 841 2018-06-11 23:21:02.409  sgPKUJiBjimhr2s_QB8qc_v8tSrwuAPh      2446
# 842 2018-06-11 23:21:49.266  iR5-bY_MsbjXr_x-4dW_gW74q9N-QQ4u      1178
# 843 2018-06-11 23:21:54.316  bc_BKpnydxdwN3fobxAahp0IIi0zaRK-      6353
# 844 2018-06-11 23:22:14.971  gni976f7oJAqbJCoOd9N7pupYq43qujw      2129
# 845 2018-06-11 23:22:23.870  vdwOxTl44vuWC0A5TwPeEv6vefzwq_km      1788
# 846 2018-06-11 23:24:07.069  jBd8xbWHLj4TgB7oX3HOBC0KTbFfjcYz      7008
# 847 2018-06-11 23:25:32.053  YVdNa9_EYKtr6v3MsISPDTpbOOqc8UV1      5080
# 848 2018-06-11 23:25:57.417  x9QvNgVggF0cmyvwXIOYqRYwNzVhAC8-      2253
# 849 2018-06-11 23:26:15.156  oGBSLErb9ojEDrPo4zBiF2Jxkhhd0Imj      7065
# 850 2018-06-11 23:27:47.023  F33mnpSye7XguebEDnZv3d58zRg1ocyc       341
# 851 2018-06-11 23:28:14.428  wd3J0CBqIq3a6sXsEcVdhcwHI8u5wtRq       151
# 852 2018-06-11 23:29:05.024  IhC9j_5sCGle_QbqGDk8Zfs0CA2C0_WN      2253
# 853 2018-06-11 23:31:02.967  ByjihO4i9HyJtDBaEYZTgGapQRl0srhp      1179
# 854 2018-06-11 23:33:10.925  Rt9pp-Nj0ZA2ghpYOXJigx-kqwavj6ux       464
# 856 2018-06-11 23:35:54.866  p0hSaKt6SB7JMixFmJ2TD894gHXAcRbd      3250
# 857 2018-06-11 23:36:54.233  WKdEu2vaRQdxSxhLo_awXazp9IDbUvlB      3214
# 858 2018-06-11 23:37:31.007  8iWks3LHh9IBCfAmW9hv5-Tuo9zlS2zV      6325
# 859 2018-06-11 23:43:56.024  N4nPtX8sba_h_k4EruRExPVQ8OwYQgjp      2486
# 860 2018-06-11 23:44:16.646  i3Rg1dmp-wTX_b9t_XoMtSA26roM6kaM       591
# 861 2018-06-11 23:45:45.035  G_FTWV3XOR8MmW01cOQVp07Q8_TznG8r       747
# 862 2018-06-11 23:47:02.003  i_Ar2GyU8xAEeQwzJm6wr60VDB6ofOpK      1065
# 863 2018-06-11 23:50:42.202  49JWS9E7KuSnvv1B7uqMnsiT82ZmtRlO       502
# 864 2018-06-11 23:51:54.449  wuK4KeAhonDy4KHxO8D60fFQsxoo_34c      5318
# 865 2018-06-11 23:54:11.765  GU1JdCza2vj7N-0_YN3JOftW7SRXkWDi      2989
# 866 2018-06-11 23:57:47.896  6xq2ibp39i7HaiTt_dOwWfpMC5UlFLhJ      1659
#
#      shop_id  price  timestamp(year)  timestamp(month)  timestamp(day)  \
# 0         38  45000             2018                 6              11
# 1         12   9500             2018                 6              11
# 3         46  29800             2018                 6              11
# 4         89  29000             2018                 6              11
# 5         22  11200             2018                 6              11
# 6         22  19800             2018                 6              11
# 7         60  23500             2018                 6              11
# 8        170  25000             2018                 6              11
# 9         22  12900             2018                 6              11
# 10        19  26500             2018                 6              11
# 11        28  23900             2018                 6              11
# 12        65  29700             2018                 6              11
# 13       102  13500             2018                 6              11
# 14        59  13500             2018                 6              11
# 15         2  18500             2018                 6              11
# 16        22  24700             2018                 6              11
# 17        91   2500             2018                 6              11
# 18        79  35800             2018                 6              11
# 19        98  29000             2018                 6              11
# 20        63  18900             2018                 6              11
# 21       126  23900             2018                 6              11
# 22       138   9900             2018                 6              11
# 23        22  10900             2018                 6              11
# 24       124  19800             2018                 6              11
# 25        43  32000             2018                 6              11
# 26        12   4500             2018                 6              11
# 27        22   6900             2018                 6              11
# 28       139  46000             2018                 6              11
# 29       179  16900             2018                 6              11
# 30       171  13600             2018                 6              11
# ..       ...    ...              ...               ...             ...
# 835       33   9000             2018                 6              11
# 837       22  19500             2018                 6              11
# 838       19  35000             2018                 6              11
# 839       12  12800             2018                 6              11
# 840      138   6900             2018                 6              11
# 841       12   5900             2018                 6              11
# 842       94  19800             2018                 6              11
# 843       22  14800             2018                 6              11
# 844       32  24800             2018                 6              11
# 845       12   9500             2018                 6              11
# 846       18  40000             2018                 6              11
# 847       64  35900             2018                 6              11
# 848      178  33000             2018                 6              11
# 849        6  29900             2018                 6              11
# 850       79  27800             2018                 6              11
# 851      126   9900             2018                 6              11
# 852      178  33000             2018                 6              11
# 853       84  19000             2018                 6              11
# 854       12  11700             2018                 6              11
# 856      192   3900             2018                 6              11
# 857        2  17800             2018                 6              11
# 858       22  11400             2018                 6              11
# 859       84   5900             2018                 6              11
# 860       28  23900             2018                 6              11
# 861       22   4500             2018                 6              11
# 862       61  29000             2018                 6              11
# 863       12  12900             2018                 6              11
# 864      181  13200             2018                 6              11
# 865       19  18900             2018                 6              11
# 866       22  19000             2018                 6              11
#
#      timestamp(hour)  timestamp(minute)  timestamp(second)  \
# 0                  0                  0                 43
# 1                  0                  2                 33
# 3                  0                  4                 17
# 4                  0                  5                 26
# 5                  0                  5                 35
# 6                  0                  6                 14
# 7                  0                  8                 39
# 8                  1                 11                 36
# 9                  0                 11                 30
# 10                 0                 12                 12
# 11                 0                 13                 40
# 12                 0                 14                 32
# 13                 0                 14                 53
# 14                 0                 16                 24
# 15                 0                 16                 58
# 16                10                 53                 34
# 17                 0                 16                 59
# 18                 0                 17                  5
# 19                 0                 17                  8
# 20                 0                 17                 45
# 21                 0                 18                 21
# 22                 0                 18                 42
# 23                 0                 32                 50
# 24                 0                 18                 45
# 25                 0                 20                 15
# 26                 0                 21                 10
# 27                 0                 36                 33
# 28                 0                 21                 16
# 29                 0                 21                 55
# 30                 0                 22                 20
# ..               ...                ...                ...
# 835               23                 17                 24
# 837               23                 19                 11
# 838               23                 19                 22
# 839               23                 19                 58
# 840               23                 21                  2
# 841               23                 21                  2
# 842               23                 21                 49
# 843               23                 21                 54
# 844               23                 22                 14
# 845               23                 22                 23
# 846               23                 24                  7
# 847               23                 25                 32
# 848               23                 25                 57
# 849               23                 26                 15
# 850               23                 27                 47
# 851               23                 28                 14
# 852               23                 29                  5
# 853               23                 31                  2
# 854               23                 33                 10
# 856               23                 35                 54
# 857               23                 36                 54
# 858               23                 37                 31
# 859               23                 43                 56
# 860               23                 44                 16
# 861               23                 45                 45
# 862               23                 47                  2
# 863               23                 50                 42
# 864               23                 51                 54
# 865               23                 54                 11
# 866               23                 57                 47
#
#     timestamp(dayofweek)   os  age age_0
# 0                 Monday  iOS   39    30
# 1                 Monday  And   17    10
# 3                 Monday  And   34    30
# 4                 Monday  And   17    10
# 5                 Monday  iOS   21    20
# 6                 Monday  iOS   22    20
# 7                 Monday  iOS   24    20
# 8                 Monday  iOS   24    20
# 9                 Monday  And   27    20
# 10                Monday  iOS   44    40
# 11                Monday  iOS   24    20
# 12                Monday  iOS   28    20
# 13                Monday  iOS   19    10
# 14                Monday  And   15    10
# 15                Monday  iOS   26    20
# 16                Monday  iOS   26    20
# 17                Monday  iOS   15    10
# 18                Monday  iOS   31    30
# 19                Monday  And   29    20
# 20                Monday  iOS   28    20
# 21                Monday  iOS   26    20
# 22                Monday  iOS   17    10
# 23                Monday  iOS   17    10
# 24                Monday  iOS   18    10
# 25                Monday  And   36    30
# 26                Monday  And   16    10
# 27                Monday  And   16    10
# 28                Monday  iOS   27    20
# 29                Monday  iOS   18    10
# 30                Monday  And   27    20
# ..                   ...  ...  ...   ...
# 835               Monday  iOS   27    20
# 837               Monday  iOS   16    10
# 838               Monday  iOS   27    20
# 839               Monday  iOS   16    10
# 840               Monday  And   16    10
# 841               Monday  And   27    20
# 842               Monday  And   30    30
# 843               Monday  And   24    20
# 844               Monday  iOS   33    30
# 845               Monday  And   16    10
# 846               Monday  iOS   31    30
# 847               Monday  And   20    20
# 848               Monday  iOS   24    20
# 849               Monday  And   22    20
# 850               Monday  iOS   25    20
# 851               Monday  iOS   22    20
# 852               Monday  And   19    10
# 853               Monday  And   15    10
# 854               Monday  And   18    10
# 856               Monday  And   15    10
# 857               Monday  iOS   32    30
# 858               Monday  iOS   20    20
# 859               Monday  And   18    10
# 860               Monday  iOS   19    10
# 861               Monday  And   16    10
# 862               Monday  iOS   15    10
# 863               Monday  And   19    10
# 864               Monday  And   26    20
# 865               Monday  iOS   27    20
# 866               Monday  And   17    10
#
# [824 rows x 15 columns]

# %%
# 상점 정보와 상품 정보 연결
goods_shop_info = pd.merge(goods_info, shop_info, on = 'shop_id', how='inner')

goods_shop_info.head()
# Out:
#    goods_id  shop_id category_x  price    name category_y                age  \
# 0         1      153         상의  17000  Joleen         의류  10대/20대 초반/20대 중반
# 1        20      153         바지  17500  Joleen         의류  10대/20대 초반/20대 중반
# 2        90      153        원피스  39000  Joleen         의류  10대/20대 초반/20대 중반
# 3       222      153        아우터  29000  Joleen         의류  10대/20대 초반/20대 중반
# 4       595      153         바지  25000  Joleen         의류  10대/20대 초반/20대 중반
#
#      style
# 0  유니크/빈티지
# 1  유니크/빈티지
# 2  유니크/빈티지
# 3  유니크/빈티지
# 4  유니크/빈티지

# %%
# 상점 순으로 정렬
goods_shop_info.sort_values(by="shop_id", ascending=True).head()
# Out:
#       goods_id  shop_id category_x  price  name category_y  \
# 4515      4751        1         상의  23000  Edna         의류
# 4513      4530        1        원피스  39000  Edna         의류
# 4512      4338        1        원피스  40800  Edna         의류
# 4511      4337        1         상의  15900  Edna         의류
# 4510      4336        1         바지  15800  Edna         의류
#
#                        age     style
# 4515  20대 중반/20대 후반/30대 초반  모던시크/러블리
# 4513  20대 중반/20대 후반/30대 초반  모던시크/러블리
# 4512  20대 중반/20대 후반/30대 초반  모던시크/러블리
# 4511  20대 중반/20대 후반/30대 초반  모던시크/러블리
# 4510  20대 중반/20대 후반/30대 초반  모던시크/러블리

# %%
user_order = pd.merge(order_user_info_clear_age, goods_shop_info, on = 'goods_id', how='inner')

print(user_order.shape)

user_order.head()
# Out:
# (824, 22)
#                 timestamp                           user_id  goods_id  \
# 0 2018-06-11 00:00:43.032  bvu0aLTqiFDoU-963xnr5nzQWTNLUMjx      1414
# 1 2018-06-11 00:02:33.763  smDmRnykg61KajpxXKzQ0oNkrh2nuSBj      1351
# 2 2018-06-11 00:04:17.258  KQBGi33Zxh5Dgu0WEkOkjN0YqTT_wxC3      5901
# 3 2018-06-11 00:05:26.010  lq1Je3voA3a0MouSFba3629lKCvweI24      5572
# 4 2018-06-11 22:34:03.339  BnyXBZ5yDOjwXoc_j2bG8k5NEWn2z6a7      5572
#
#    shop_id_x  price_x  timestamp(year)  timestamp(month)  timestamp(day)  \
# 0         38    45000             2018                 6              11
# 1         12     9500             2018                 6              11
# 2         46    29800             2018                 6              11
# 3         89    29000             2018                 6              11
# 4         89    29000             2018                 6              11
#
#    timestamp(hour)  timestamp(minute)  ...   os age_x age_0  shop_id_y  \
# 0                0                  0  ...  iOS    39    30         38
# 1                0                  2  ...  And    17    10         12
# 2                0                  4  ...  And    34    30         46
# 3                0                  5  ...  And    17    10         89
# 4               22                 34  ...  And    19    10         89
#
#   category_x  price_y      name  category_y                 age_y       style
# 0        원피스    45000     Mabel          의류  20대 후반/30대 초반/30대 중반    모던시크/페미닌
# 1         상의     9500    Rachel          의류            10대/20대 초반   러블리/심플베이직
# 2         바지    29800    Elayne          의류  20대 중반/20대 후반/30대 초반  모던시크/심플베이직
# 3         바지    29000  Margaret          의류     10대/20대 초반/20대 중반     빈티지/유니크
# 4         바지    29000  Margaret          의류     10대/20대 초반/20대 중반     빈티지/유니크
#
# [5 rows x 22 columns]

# %%
user_order["price_x"]
# Out:
# 0      45000
# 1       9500
# 2      29800
# 3      29000
# 4      29000
# 5      11200
# 6      11200
# 7      11200
# 8      11200
# 9      19800
# 10     23500
# 11     25000
# 12     12900
# 13     26500
# 14     23900
# 15     29700
# 16     13500
# 17     13500
# 18     18500
# 19     18500
# 20     24700
# 21     24700
# 22      2500
# 23      2500
# 24     35800
# 25     29000
# 26     18900
# 27     23900
# 28     23900
# 29      9900
#        ...
# 794    34000
# 795    10000
# 796    19800
# 797    29000
# 798    56800
# 799    25900
# 800    18000
# 801    20000
# 802    37000
# 803     7000
# 804     9000
# 805    35000
# 806    12800
# 807     6900
# 808     5900
# 809    19800
# 810    24800
# 811    40000
# 812    35900
# 813    27800
# 814    19000
# 815    11700
# 816     3900
# 817    17800
# 818    11400
# 819     5900
# 820    23900
# 821    29000
# 822    12900
# 823    13200
# Name: price_x, Length: 824, dtype: int64

# %% [markdown]
# ### 2. 시각화

# %%
sns.countplot(x='timestamp(hour)', hue= 'age_0', data=user_order, dodge=False, hue_order = ['45+', '40', '30', '20', '10'])

# %%
sns.countplot(x='timestamp(hour)', hue= 'category_x', data=user_order, dodge=False)
